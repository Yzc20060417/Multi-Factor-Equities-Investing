# %% [markdown]
# # Phase4: Collinearity Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import json

# %%
# %run "./Single Factor Testing.ipynb"
# Out:
# Requirement already satisfied: nbformat in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/csi/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/3468435781.py:28: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = close.pct_change()
# ===== Performance Summary =====
# Periods             : 2564
# Total Return        :    7.77%
# CAGR                :    0.74%
# Ann. Volatility     :    7.31%
# Sharpe Ratio        :     0.10
# Max Drawdown        :  -23.94%
# Calmar Ratio        :     0.03
# Hit Rate (p>0)      :   48.32%
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/2569342948.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   fwd = prices.pct_change(p).shift(-p)
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/2569342948.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   fwd = prices.pct_change(p).shift(-p)
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/2569342948.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   fwd = prices.pct_change(p).shift(-p)
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ===== Performance Summary =====
# Periods             : 2228
# Total Return        :   34.54%
# CAGR                :    3.41%
# Ann. Volatility     :    4.44%
# Sharpe Ratio        :     0.77
# Max Drawdown        :   -5.15%
# Calmar Ratio        :     0.66
# Hit Rate (p>0)      :   52.33%
# ===== Performance Summary =====
# Periods             : 2467
# Total Return        :   24.71%
# CAGR                :    2.28%
# Ann. Volatility     :    4.28%
# Sharpe Ratio        :     0.53
# Max Drawdown        :   -7.42%
# Calmar Ratio        :     0.31
# Hit Rate (p>0)      :   52.45%
# ===== Performance Summary =====
# Periods             : 2224
# Total Return        :   36.05%
# CAGR                :    3.55%
# Ann. Volatility     :    4.65%
# Sharpe Ratio        :     0.76
# Max Drawdown        :  -12.70%
# Calmar Ratio        :     0.28
# Hit Rate (p>0)      :   53.15%
# ===== Performance Summary =====
# Periods             : 2224
# Total Return        :   21.59%
# CAGR                :    2.24%
# Ann. Volatility     :    4.40%
# Sharpe Ratio        :     0.51
# Max Drawdown        :   -8.21%
# Calmar Ratio        :     0.27
# Hit Rate (p>0)      :   51.44%
# ===== Performance Summary =====
# Periods             : 2313
# Total Return        :   18.38%
# CAGR                :    1.86%
# Ann. Volatility     :    4.37%
# Sharpe Ratio        :     0.42
# Max Drawdown        :   -9.56%
# Calmar Ratio        :     0.19
# Hit Rate (p>0)      :   50.84%
# /Users/apple/Documents/GitHub/Quant/notebooks/operators_library.py:140: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cond = cond_df.reindex(val_df.index).fillna(False).astype(bool)
# ===== Performance Summary =====
# Periods             : 2048
# Total Return        :  -21.04%
# CAGR                :   -2.87%
# Ann. Volatility     :    7.75%
# Sharpe Ratio        :    -0.37
# Max Drawdown        :  -35.03%
# Calmar Ratio        :    -0.08
# Hit Rate (p>0)      :   44.14%
# ===== Performance Summary =====
# Periods             : 2469
# Total Return        :   42.97%
# CAGR                :    3.72%
# Ann. Volatility     :    7.67%
# Sharpe Ratio        :     0.48
# Max Drawdown        :  -15.57%
# Calmar Ratio        :     0.24
# Hit Rate (p>0)      :   50.63%
# ===== Performance Summary =====
# Periods             : 1795
# Total Return        :   26.94%
# CAGR                :    3.41%
# Ann. Volatility     :    4.35%
# Sharpe Ratio        :     0.78
# Max Drawdown        :   -6.72%
# Calmar Ratio        :     0.51
# Hit Rate (p>0)      :   50.97%
# ===== Performance Summary =====
# Periods             : 2707
# Total Return        :   33.78%
# CAGR                :    2.75%
# Ann. Volatility     :    6.01%
# Sharpe Ratio        :     0.46
# Max Drawdown        :  -18.41%
# Calmar Ratio        :     0.15
# Hit Rate (p>0)      :   51.57%
# ===== Performance Summary =====
# Periods             : 2753
# Total Return        :   50.78%
# CAGR                :    3.83%
# Ann. Volatility     :   15.69%
# Sharpe Ratio        :     0.24
# Max Drawdown        :  -47.45%
# Calmar Ratio        :     0.08
# Hit Rate (p>0)      :   52.16%
# ===== Performance Summary =====
# Periods             : 2325
# Total Return        :  -18.92%
# CAGR                :   -2.25%
# Ann. Volatility     :    7.77%
# Sharpe Ratio        :    -0.29
# Max Drawdown        :  -23.64%
# Calmar Ratio        :    -0.10
# Hit Rate (p>0)      :   32.73%
# ===== Performance Summary =====
# Periods             : 2816
# Total Return        :   -5.89%
# CAGR                :   -0.54%
# Ann. Volatility     :    5.25%
# Sharpe Ratio        :    -0.10
# Max Drawdown        :  -20.12%
# Calmar Ratio        :    -0.03
# Hit Rate (p>0)      :   50.53%
# ===== Performance Summary =====
# Periods             : 2713
# Total Return        :   24.76%
# CAGR                :    2.08%
# Ann. Volatility     :    6.49%
# Sharpe Ratio        :     0.32
# Max Drawdown        :  -21.57%
# Calmar Ratio        :     0.10
# Hit Rate (p>0)      :   50.79%
# ===== Performance Summary =====
# Periods             : 1795
# Total Return        :   29.33%
# CAGR                :    3.68%
# Ann. Volatility     :    4.89%
# Sharpe Ratio        :     0.75
# Max Drawdown        :   -6.91%
# Calmar Ratio        :     0.53
# Hit Rate (p>0)      :   50.19%
# ===== Performance Summary =====
# Periods             : 2608
# Total Return        :   -7.83%
# CAGR                :   -0.78%
# Ann. Volatility     :    5.94%
# Sharpe Ratio        :    -0.13
# Max Drawdown        :  -27.80%
# Calmar Ratio        :    -0.03
# Hit Rate (p>0)      :   49.73%
# /Users/apple/Documents/GitHub/Quant/notebooks/operators_library.py:140: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cond = cond_df.reindex(val_df.index).fillna(False).astype(bool)
# ===== Performance Summary =====
# Periods             : 2471
# Total Return        :   19.92%
# CAGR                :    1.87%
# Ann. Volatility     :    4.68%
# Sharpe Ratio        :     0.40
# Max Drawdown        :  -10.50%
# Calmar Ratio        :     0.18
# Hit Rate (p>0)      :   51.84%
# ===== Performance Summary =====
# Periods             : 1796
# Total Return        :    5.20%
# CAGR                :    0.71%
# Ann. Volatility     :    4.97%
# Sharpe Ratio        :     0.14
# Max Drawdown        :  -16.41%
# Calmar Ratio        :     0.04
# Hit Rate (p>0)      :   50.11%
# /Users/apple/Documents/GitHub/Quant/notebooks/operators_library.py:140: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cond = cond_df.reindex(val_df.index).fillna(False).astype(bool)
# ===== Performance Summary =====
# Periods             : 2628
# Total Return        :    7.38%
# CAGR                :    0.69%
# Ann. Volatility     :    6.57%
# Sharpe Ratio        :     0.10
# Max Drawdown        :  -19.99%
# Calmar Ratio        :     0.03
# Hit Rate (p>0)      :   50.23%
# ===== Performance Summary =====
# Periods             : 1737
# Total Return        :    6.85%
# CAGR                :    0.97%
# Ann. Volatility     :    5.98%
# Sharpe Ratio        :     0.16
# Max Drawdown        :  -12.18%
# Calmar Ratio        :     0.08
# Hit Rate (p>0)      :   48.93%
# ===== Performance Summary =====
# Periods             : 2629
# Total Return        :   -6.05%
# CAGR                :   -0.60%
# Ann. Volatility     :    7.78%
# Sharpe Ratio        :    -0.08
# Max Drawdown        :  -21.92%
# Calmar Ratio        :    -0.03
# Hit Rate (p>0)      :   49.60%

# %% [markdown]
# ## Benchmark: Stoxx50

# %%
def benchmark_returns(stoxx_df, start_date=None, end_date=None):
    """
    stoxx_df: DataFrame with index=dates and column '收盘'
    start_date, end_date: 'YYYY-MM-DD' strings or None
    """
    df = stoxx_df.copy()
    if start_date is not None:
        df = df.loc[df.index >= pd.to_datetime(start_date)]
    if end_date is not None:
        df = df.loc[df.index <= pd.to_datetime(end_date)]

    close = df['收盘']
    ret = close.pct_change()          # daily returns
    ret = ret.replace([np.inf, -np.inf], np.nan).dropna()
    return ret

stoxx = pd.read_csv('/Users/apple/Desktop/Data/Indices/EuroStoxx50.csv')
stoxx['交易日期'] = pd.to_datetime(stoxx['交易日期'])
stoxx = stoxx.sort_values('交易日期').set_index('交易日期')

stoxx['收盘'] = (
    stoxx['收盘']
    .astype(str)         
    .str.replace(',', '')
    .str.strip()              
)

stoxx['收盘'] = pd.to_numeric(stoxx['收盘'], errors='coerce')
# choose your window
start = "2017-03-01"
end   = "2025-12-31"

bench_pnl = benchmark_returns(stoxx, start, end)

performance_summary(bench_pnl, periods_per_year=252)
plot_equity_curve(bench_pnl, title="EuroStoxx50 Benchmark")
# Out:
# ===== Performance Summary =====
# Periods             : 2253
# Total Return        :   78.14%
# CAGR                :    6.67%
# Ann. Volatility     :   20.20%
# Sharpe Ratio        :     0.33
# Max Drawdown        :  -42.52%
# Calmar Ratio        :     0.16
# Hit Rate (p>0)      :   53.40%
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/3272765553.py:13: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = close.pct_change()          # daily returns

# %% [markdown]
# ## 4.1 Data Cleaning

# %% [markdown]
# ## 4.1.1 Helpers

# %%
# Helpers
def _simplify_columns(df: pd.DataFrame) -> pd.DataFrame:
    """If columns are MultiIndex with constant metadata levels, drop those levels."""
    out = df.copy()
    if isinstance(out.columns, pd.MultiIndex):
        keep_levels = []
        for i in range(out.columns.nlevels):
            if out.columns.get_level_values(i).nunique() > 1:
                keep_levels.append(i)
        if len(keep_levels) == 1:
            out.columns = out.columns.get_level_values(keep_levels[0])
        else:
            out.columns = pd.Index(["|".join(map(str, tup)) for tup in out.columns.to_list()])
    out.columns = pd.Index([str(c).strip() for c in out.columns])
    return out

def _ensure_datetime_index(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    if not isinstance(out.index, pd.DatetimeIndex):
        out.index = pd.to_datetime(out.index)
    out = out[~out.index.duplicated(keep="last")]
    out = out.sort_index()
    return out

def _to_numeric(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    for c in out.columns:
        out[c] = pd.to_numeric(out[c], errors="coerce")
    out = out.replace([np.inf, -np.inf], np.nan)
    return out

def _cs_winsorize(df: pd.DataFrame, lo=0.01, hi=0.99, min_n=10) -> pd.DataFrame:
    """Winsorize cross-sectionally per date."""
    def _clip_row(x):
        x = x.astype(float)
        m = x.notna()
        if m.sum() < min_n:
            return x
        ql = x[m].quantile(lo)
        qh = x[m].quantile(hi)
        return x.clip(ql, qh)
    return df.apply(_clip_row, axis=1)

def _cs_zscore(df: pd.DataFrame, min_n=10) -> pd.DataFrame:
    """Z-score cross-sectionally per date (mean/std on available names)."""
    def _zrow(x):
        x = x.astype(float)
        m = x.notna()
        if m.sum() < min_n:
            return x * np.nan
        mu = x[m].mean()
        sd = x[m].std(ddof=0)
        if sd == 0 or np.isnan(sd):
            return x * np.nan
        out = (x - mu) / sd
        return out
    return df.apply(_zrow, axis=1)

def _cs_rank(df: pd.DataFrame, min_n=10, method="average") -> pd.DataFrame:
    """Cross-sectional ranks scaled to [-0.5, 0.5] (robust for small universes)."""
    def _rrow(x):
        x = x.astype(float)
        m = x.notna()
        if m.sum() < min_n:
            return x * np.nan
        r = x[m].rank(method=method, ascending=True)
        # map ranks to (0,1), then center to (-0.5,0.5)
        u = (r - 0.5) / m.sum()
        out = pd.Series(np.nan, index=x.index, dtype=float)
        out.loc[m] = u - 0.5
        return out
    return df.apply(_rrow, axis=1)

# %% [markdown]
# ## 4.1.2 Pre-Processing

# %%
# 1) Collect alpha pool
alpha_names = (
    ["alpha_nltsmom"]
    + [f"alpha{i}" for i in range(1, 25) if i not in (14, 20, 23)]
)

alpha_pool = {}
missing = []
wrong_type = []

for name in alpha_names:
    if name not in globals():
        missing.append(name)
        continue
    obj = globals()[name]
    if not isinstance(obj, pd.DataFrame):
        wrong_type.append((name, type(obj)))
        continue
    alpha_pool[name] = obj

print(f"Requested {len(alpha_names)} alphas.")
print(f"Collected  {len(alpha_pool)} DataFrames.")

if missing:
    print("Missing variables:", missing)
if wrong_type:
    print("Wrong type (expected pd.DataFrame):", wrong_type)
# Out:
# Requested 22 alphas.
# Collected  22 DataFrames.

# %%
# 2) normalize each alpha: columns, datetime index, numeric
for k in list(alpha_pool.keys()):
    df = alpha_pool[k]
    df = _simplify_columns(df)
    df = _ensure_datetime_index(df)
    df = _to_numeric(df)
    alpha_pool[k] = df

# %%
# 3) Define master calendar + ticker set (using px_close)
# -----------------------------
# Set this once if your variable name differs:
# px_close = <YOUR CLOSE DF>
px_close = _simplify_columns(_ensure_datetime_index(_to_numeric(close_df)))

tickers_common = set(px_close.columns)
for k, df in alpha_pool.items():
    tickers_common &= set(df.columns)

tickers_common = sorted(tickers_common)
print(f"Common tickers across prices + all alphas: {len(tickers_common)}")

master_index = px_close.index  # use price calendar as source of truth

# align all alphas to master index + common tickers
alpha_aligned = {}
for k, df in alpha_pool.items():
    alpha_aligned[k] = df.reindex(index=master_index, columns=tickers_common)

px_close = px_close.reindex(index=master_index, columns=tickers_common)

# tradable universe mask (minimum): we can only trade names with a close price
univ = px_close.notna()
# Out:
# Common tickers across prices + all alphas: 50

# %%
# 4) Coverage report
# -----------------------------
def build_coverage_table(alpha_aligned: dict, univ: pd.DataFrame) -> pd.DataFrame:
    rows = []
    idx = univ.index
    for k, df in alpha_aligned.items():
        m = df.notna() & univ
        any_day = m.any(axis=1)
        start = any_day.idxmax() if any_day.any() else pd.NaT
        rows.append({
            "alpha": k,
            "start_date_nonnull": start,
            "end_date": idx.max(),
            "avg_names_per_day": float(m.sum(axis=1).mean()),
            "median_names_per_day": float(m.sum(axis=1).median()),
            "overall_coverage_frac": float(m.sum().sum() / univ.sum().sum()),
        })
    return pd.DataFrame(rows).sort_values("overall_coverage_frac", ascending=False).reset_index(drop=True)

coverage = build_coverage_table(alpha_aligned, univ)
display(coverage)

# Optional: quick sanity checks
assert px_close.index.is_monotonic_increasing
for k, df in alpha_aligned.items():
    assert df.index.equals(master_index), f"{k} index misaligned"
    assert list(df.columns) == tickers_common, f"{k} columns misaligned"
# Out:
#             alpha start_date_nonnull   end_date  avg_names_per_day  \
# 0         alpha11         2014-12-30 2025-12-31          48.423855
# 1          alpha7         2014-12-30 2025-12-31          48.423855
# 2         alpha19         2015-01-02 2025-12-31          48.416755
# 3          alpha9         2015-06-08 2025-12-31          46.660987
# 4         alpha12         2014-12-30 2025-12-31          46.384807
# 5   alpha_nltsmom         2015-12-28 2025-12-31          43.950302
# 6         alpha10         2015-03-30 2025-12-31          39.325169
# 7          alpha5         2016-12-15 2025-12-31          39.020234
# 8         alpha17         2016-05-09 2025-12-31          32.448704
# 9          alpha6         2017-03-27 2025-12-31          31.164004
# 10         alpha2         2016-05-13 2025-12-31          28.803337
# 11        alpha13         2015-05-29 2025-12-31          28.631523
# 12      alpha_pv1         2017-04-24 2025-12-31          27.461839
# 13         alpha4         2017-04-28 2025-12-31          27.420660
# 14         alpha3         2017-04-28 2025-12-31          27.402911
# 15        alpha16         2015-01-02 2025-12-31          27.270501
# 16        alpha18         2018-12-24 2025-12-31          23.340078
# 17        alpha15         2018-12-27 2025-12-31          23.096912
# 18        alpha24         2015-09-24 2025-12-31          22.404686
# 19        alpha21         2015-09-25 2025-12-31          22.384807
# 20         alpha8         2018-12-27 2025-12-31          22.384452
# 21        alpha22         2019-03-20 2025-12-31          15.955627
#
#     median_names_per_day  overall_coverage_frac
# 0                   49.0               1.000000
# 1                   49.0               1.000000
# 2                   49.0               0.999853
# 3                   49.0               0.963595
# 4                   47.0               0.957892
# 5                   48.0               0.907617
# 6                   49.0               0.812103
# 7                   49.0               0.805806
# 8                   42.0               0.670098
# 9                   43.0               0.643567
# 10                  42.0               0.594817
# 11                  38.0               0.591269
# 12                  43.0               0.567114
# 13                  43.0               0.566263
# 14                  43.0               0.565897
# 15                  26.0               0.563163
# 16                  26.0               0.481995
# 17                  26.0               0.476974
# 18                  22.0               0.462679
# 19                  22.0               0.462268
# 20                  26.0               0.462261
# 21                  20.0               0.329499

# %%
# 5) Robust cross-sectional cleaning (analysis-ready exposures)
# -----------------------------
alpha_clip_z = {}
alpha_rank = {}

for k, df in alpha_aligned.items():
    # keep values only where tradable
    x = df.where(univ)

    # winsorize then z-score (classic)
    xw = _cs_winsorize(x, lo=0.01, hi=0.99, min_n=10)
    xz = _cs_zscore(xw, min_n=10)

    # rank version (often best for STOXX50)
    xr = _cs_rank(x, min_n=10)

    alpha_clip_z[k] = xz
    alpha_rank[k] = xr

print("Built cleaned alpha versions:")
print(" - alpha_aligned: raw aligned")
print(" - alpha_clip_z: winsorized + cross-sectional z-score")
print(" - alpha_rank: cross-sectional ranks in [-0.5, 0.5]")
# Out:
# Built cleaned alpha versions:
#  - alpha_aligned: raw aligned
#  - alpha_clip_z: winsorized + cross-sectional z-score
#  - alpha_rank: cross-sectional ranks in [-0.5, 0.5]

# %% [markdown]
# ## Diagnostics

# %%
# 1) Choose factor subsets by coverage thresholds
# ---------------------------
def select_alphas_by_coverage(coverage: pd.DataFrame,
                             min_overall=0.60,
                             min_median_names=30) -> list[str]:
    m = (coverage["overall_coverage_frac"] >= min_overall) & (coverage["median_names_per_day"] >= min_median_names)
    return coverage.loc[m, "alpha"].tolist()

alphas_core = select_alphas_by_coverage(coverage, min_overall=0.80, min_median_names=45)   # high-quality set
alphas_pool = select_alphas_by_coverage(coverage, min_overall=0.55, min_median_names=25)   # broad pool (like your ~0.56 group)

print("Core set (high coverage):", alphas_core)
print("Broad pool (looser thresholds):", alphas_pool)

# ---------------------------
# 2) Build a "common-live" date mask
# ---------------------------
def common_date_mask(alpha_aligned: dict,
                     univ: pd.DataFrame,
                     alphas: list[str],
                     min_names_per_alpha_per_day=30,
                     require_frac_alphas=0.9) -> pd.Series:
    """
    For each day, check each alpha has >= min_names_per_alpha_per_day non-missing tradable names.
    Keep day if at least require_frac_alphas of alphas satisfy.
    """
    ok_matrix = []
    for k in alphas:
        m = alpha_aligned[k].notna() & univ
        ok = (m.sum(axis=1) >= min_names_per_alpha_per_day)
        ok_matrix.append(ok.rename(k))
    ok_df = pd.concat(ok_matrix, axis=1)
    frac_ok = ok_df.mean(axis=1)
    return frac_ok >= require_frac_alphas

# Example: common sample for the broad pool (tune thresholds)
mask_common = common_date_mask(alpha_aligned, univ, alphas=alphas_pool,
                               min_names_per_alpha_per_day=30,
                               require_frac_alphas=0.9)

print("Common-sample days:", int(mask_common.sum()), "out of", len(mask_common))
if mask_common.any():
    print("Common-sample start:", mask_common.idxmax())
    print("Common-sample end:", mask_common[mask_common].index.max())

# ---------------------------
# 3) Define explicit window starts based on latest factor "turn-on"
# ---------------------------
def window_from_latest_start(coverage: pd.DataFrame, alphas: list[str]) -> pd.Timestamp:
    s = coverage.set_index("alpha").loc[alphas, "start_date_nonnull"]
    return pd.to_datetime(s.max())

latest_start_pool = window_from_latest_start(coverage, alphas_pool)
latest_start_core = window_from_latest_start(coverage, alphas_core)

print("Latest start (broad pool):", latest_start_pool)
print("Latest start (core set):", latest_start_core)
# Out:
# Core set (high coverage): ['alpha11', 'alpha7', 'alpha19', 'alpha9', 'alpha12', 'alpha_nltsmom', 'alpha10', 'alpha5']
# Broad pool (looser thresholds): ['alpha11', 'alpha7', 'alpha19', 'alpha9', 'alpha12', 'alpha_nltsmom', 'alpha10', 'alpha5', 'alpha17', 'alpha6', 'alpha2', 'alpha13', 'alpha_pv1', 'alpha4', 'alpha3', 'alpha16']
# Common-sample days: 1272 out of 2817
# Common-sample start: 2019-12-19 00:00:00
# Common-sample end: 2025-12-23 00:00:00
# Latest start (broad pool): 2017-04-28 00:00:00
# Latest start (core set): 2016-12-15 00:00:00

# %% [markdown]
# ## 4.1.3 Analysis Panels

# %%
# - alpha_rank: dict[name -> df]  (cross-sectional ranks, aligned)
# - alpha_clip_z: dict[name -> df] (winsorized + cs zscore, aligned)
# - px_close: DataFrame of close prices aligned to same index/columns
# - univ: boolean tradable mask, typically px_close.notna()
# - mask_common: boolean Series on dates (your common-sample date mask)
# - alphas_pool (or alphas_core): list[str] of factor names to include

ALPHAS = alphas_pool          # <-- choose: alphas_core or alphas_pool
DATE_MASK = mask_common       # <-- your chosen date mask
H = 1                         # forward horizon in days (set 5, 20 later if needed)

# ---------------------------
# 1) Forward returns (simple close-to-close)
# ---------------------------
# R_fwd is indexed by "signal date" t, whose return is from t -> t+H
R_fwd = px_close.pct_change(H).shift(-H)
R_fwd = R_fwd.where(univ)

# Restrict to chosen dates
R_fwd = R_fwd.loc[DATE_MASK]

# ---------------------------
# 2) Stack factors into a single panel (MultiIndex columns)
# ---------------------------
def stack_alpha_dict(alpha_dict: dict, alphas: list[str], date_mask: pd.Series) -> pd.DataFrame:
    frames = []
    for a in alphas:
        df = alpha_dict[a].loc[date_mask]  # date-filtered
        # columns -> MultiIndex (alpha, ticker)
        df.columns = pd.MultiIndex.from_product([[a], df.columns], names=["alpha", "ticker"])
        frames.append(df)
    X = pd.concat(frames, axis=1).sort_index(axis=1)
    return X

X_rank = stack_alpha_dict(alpha_rank, ALPHAS, DATE_MASK)
X_z    = stack_alpha_dict(alpha_clip_z, ALPHAS, DATE_MASK)

print("X_rank shape:", X_rank.shape, "  (#dates x (#alphas * #tickers))")
print("X_z    shape:", X_z.shape)
print("R_fwd  shape:", R_fwd.shape)

# ---------------------------
# 3) Build a sample mask requiring sufficient data per day
# ---------------------------
# For each day and ticker, require:
# - tradable (univ True)
# - returns available
# - at least K factors non-missing (so regression/corr isn't junk)
K_MIN_FACTORS = max(5, int(0.7 * len(ALPHAS)))   # e.g. require 70% of factors available

# Count how many factor exposures are available per (date,ticker)
# reshape X_rank to (date, alpha, ticker) via stack/unstack
avail = X_rank.notna()
# convert MultiIndex columns -> count per ticker
avail_counts = avail.groupby(level="ticker", axis=1).sum()  # sum over alpha columns per ticker
# avail_counts: (date x ticker) = #non-missing alphas

sample_mask = (univ.loc[DATE_MASK] &
               R_fwd.notna() &
               (avail_counts >= K_MIN_FACTORS))

print("K_MIN_FACTORS =", K_MIN_FACTORS)
print("Avg names/day in sample:", float(sample_mask.sum(axis=1).mean()))
print("Median names/day in sample:", float(sample_mask.sum(axis=1).median()))

# Apply sample mask to returns
R_fwd_s = R_fwd.where(sample_mask)

# Quick diagnostics
bad_days = sample_mask.sum(axis=1).sort_values().head(10)
display(bad_days.rename("names_in_sample_bottom10"))
# Out:
# X_rank shape: (1272, 800)   (#dates x (#alphas * #tickers))
# X_z    shape: (1272, 800)
# R_fwd  shape: (1272, 50)
# K_MIN_FACTORS = 11
# Avg names/day in sample: 47.9811320754717
# Median names/day in sample: 48.0
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/1219764327.py:16: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   R_fwd = px_close.pct_change(H).shift(-H)
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/1219764327.py:55: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   avail_counts = avail.groupby(level="ticker", axis=1).sum()  # sum over alpha columns per ticker
# Date
# 2020-11-26    43
# 2022-08-15    43
# 2020-08-27    43
# 2020-11-23    43
# 2020-03-12    43
# 2020-11-30    43
# 2020-10-21    44
# 2020-10-19    44
# 2020-05-27    44
# 2020-04-21    44
# Name: names_in_sample_bottom10, dtype: int64

# %% [markdown]
# ## Degenerate Factors Filter

# %%
ALPHAS = alphas_pool        # or alphas_core
DATE_MASK = mask_common
MIN_NAMES = 30              # same scale as your sample rules
MIN_CS_STD = 1e-6           # for rank panel; use larger (e.g. 1e-3) for z panel

def factor_viability_mask(alpha_dict, univ, alphas, date_mask, min_names=30, min_cs_std=1e-6):
    """
    Returns:
      viable[a]: Series[date] whether factor a is usable on that date
      stats: DataFrame with viability summary per factor
    """
    viable = {}
    rows = []

    for a in alphas:
        x = alpha_dict[a].loc[date_mask].where(univ.loc[date_mask])
        n = x.notna().sum(axis=1)
        cs_std = x.std(axis=1, skipna=True)

        v = (n >= min_names) & (cs_std > min_cs_std)
        viable[a] = v

        rows.append({
            "alpha": a,
            "viable_day_frac": float(v.mean()),
            "avg_names_when_viable": float(n[v].mean()) if v.any() else np.nan,
            "median_names_when_viable": float(n[v].median()) if v.any() else np.nan,
            "median_cs_std": float(cs_std.median()),
            "zero_std_day_frac": float((cs_std.fillna(0) == 0).mean()),
        })

    stats = pd.DataFrame(rows).sort_values("viable_day_frac", ascending=False).reset_index(drop=True)
    return viable, stats

viable_rank, viable_stats_rank = factor_viability_mask(
    alpha_rank, univ, ALPHAS, DATE_MASK, min_names=MIN_NAMES, min_cs_std=MIN_CS_STD
)

display(viable_stats_rank)
# Out:
#             alpha  viable_day_frac  avg_names_when_viable  \
# 0          alpha7         1.000000              49.884434
# 1         alpha19         1.000000              49.882862
# 2          alpha9         1.000000              49.884434
# 3         alpha12         1.000000              47.924528
# 4   alpha_nltsmom         1.000000              49.680031
# 5          alpha5         1.000000              49.884434
# 6         alpha17         1.000000              46.673742
# 7          alpha2         1.000000              43.193396
# 8         alpha13         1.000000              41.483491
# 9       alpha_pv1         1.000000              43.301887
# 10         alpha4         1.000000              43.301101
# 11         alpha3         1.000000              43.297170
# 12         alpha6         0.969340              47.631792
# 13        alpha11         0.744497              49.873284
# 14        alpha10         0.172956              49.890909
# 15        alpha16         0.000000                    NaN
#
#     median_names_when_viable  median_cs_std  zero_std_day_frac
# 0                       50.0       0.291345           0.000000
# 1                       50.0       0.291548           0.000000
# 2                       50.0       0.291513           0.000000
# 3                       49.0       0.291598           0.000000
# 4                       50.0       0.291548           0.000000
# 5                       50.0       0.264143           0.000000
# 6                       48.0       0.291667           0.000000
# 7                       44.0       0.278060           0.000000
# 8                       42.0       0.291369           0.000000
# 9                       43.0       0.292013           0.000000
# 10                      43.0       0.292013           0.000000
# 11                      43.0       0.292013           0.000000
# 12                      49.0       0.207681           0.030660
# 13                      50.0       0.098974           0.255503
# 14                      50.0       0.000000           0.827044
# 15                       NaN       0.294392           0.000000

# %%
MIN_VIABLE_FRAC = 0.6

keep_alphas = viable_stats_rank.loc[viable_stats_rank["viable_day_frac"] >= MIN_VIABLE_FRAC, "alpha"].tolist()
drop_alphas = [a for a in ALPHAS if a not in keep_alphas]

print("Keeping alphas:", keep_alphas)
print("Dropping/flagging (low viable days):", drop_alphas)
# Out:
# Keeping alphas: ['alpha7', 'alpha19', 'alpha9', 'alpha12', 'alpha_nltsmom', 'alpha5', 'alpha17', 'alpha2', 'alpha13', 'alpha_pv1', 'alpha4', 'alpha3', 'alpha6', 'alpha11']
# Dropping/flagging (low viable days): ['alpha10', 'alpha16']

# %%
ALPHAS2 = keep_alphas

X_rank = stack_alpha_dict(alpha_rank, ALPHAS2, DATE_MASK)
X_z    = stack_alpha_dict(alpha_clip_z, ALPHAS2, DATE_MASK)
R_fwd  = px_close.pct_change(H).shift(-H).where(univ).loc[DATE_MASK]
# Out:
# /var/folders/n7/k_8ylm196lz3lzb72_x8vz340000gn/T/ipykernel_67792/20839303.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   R_fwd  = px_close.pct_change(H).shift(-H).where(univ).loc[DATE_MASK]

# %% [markdown]
# ## 4.2 Collinearity Check

# %% [markdown]
# ## 4.2.1 Spearman Correlation

# %%
from itertools import combinations

def daily_cs_corr(xi: pd.DataFrame, xj: pd.DataFrame, min_names=30):
    """
    For each day: corr across tickers between xi[t,:] and xj[t,:]
    Returns: Series indexed by date
    """
    # align
    xi, xj = xi.align(xj, join="inner", axis=0)
    corrs = []
    dates = xi.index
    for t in dates:
        a = xi.loc[t]
        b = xj.loc[t]
        m = a.notna() & b.notna()
        if m.sum() < min_names:
            corrs.append(np.nan)
        else:
            corrs.append(a[m].corr(b[m], method="spearman"))
    return pd.Series(corrs, index=dates)

def factor_corr_matrix(alpha_rank, univ, alphas, date_mask, viable=None, min_names=30):
    alphas = list(alphas)
    C = pd.DataFrame(np.nan, index=alphas, columns=alphas)
    N = pd.DataFrame(0, index=alphas, columns=alphas, dtype=int)

    # pre-mask
    X = {a: alpha_rank[a].loc[date_mask].where(univ.loc[date_mask]) for a in alphas}

    for a in alphas:
        C.loc[a, a] = 1.0
        N.loc[a, a] = int(date_mask.sum())

    for a, b in combinations(alphas, 2):
        xi, xj = X[a], X[b]

        # apply viability intersection if provided
        if viable is not None:
            v = viable[a].loc[date_mask] & viable[b].loc[date_mask]
            xi = xi.loc[v]
            xj = xj.loc[v]

        s = daily_cs_corr(xi, xj, min_names=min_names).dropna()
        C.loc[a, b] = C.loc[b, a] = float(s.mean()) if len(s) else np.nan
        N.loc[a, b] = N.loc[b, a] = int(len(s))

    return C, N

C_spear, N_eff = factor_corr_matrix(
    alpha_rank, univ, ALPHAS2, DATE_MASK, viable=viable_rank, min_names=MIN_NAMES
)

display(C_spear)
display(N_eff)
# Out:
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
#                  alpha7    alpha9   alpha12  alpha_nltsmom    alpha5  \
# alpha7         1.000000  0.064753  0.018615       0.106121 -0.072222
# alpha9         0.064753  1.000000  0.021188       0.137491  0.003992
# alpha12        0.018615  0.021188  1.000000       0.037304 -0.010941
# alpha_nltsmom  0.106121  0.137491  0.037304       1.000000 -0.041271
# alpha5        -0.072222  0.003992 -0.010941      -0.041271  1.000000
# alpha17        0.043678  0.064119  0.028756       0.182497 -0.078036
# alpha2         0.007399  0.005212 -0.000021       0.014079 -0.049608
# alpha13        0.136441  0.165599  0.209970       0.413533 -0.000762
# alpha_pv1      0.019010  0.035188 -0.020372       0.072461  0.002373
# alpha4         0.031660 -0.008760  0.014214       0.080380 -0.089462
# alpha3         0.019844 -0.014647 -0.006106      -0.036394 -0.110590
# alpha6         0.015749  0.038148  0.011518       0.005007 -0.224769
# alpha11        0.181646  0.062365  0.025838       0.232131 -0.059634
#
#                 alpha17    alpha2   alpha13  alpha_pv1    alpha4    alpha3  \
# alpha7         0.043678  0.007399  0.136441   0.019010  0.031660  0.019844
# alpha9         0.064119  0.005212  0.165599   0.035188 -0.008760 -0.014647
# alpha12        0.028756 -0.000021  0.209970  -0.020372  0.014214 -0.006106
# alpha_nltsmom  0.182497  0.014079  0.413533   0.072461  0.080380 -0.036394
# alpha5        -0.078036 -0.049608 -0.000762   0.002373 -0.089462 -0.110590
# alpha17        1.000000  0.016800  0.105335  -0.023507  0.041826  0.013098
# alpha2         0.016800  1.000000 -0.003051  -0.016780  0.021329  0.070881
# alpha13        0.105335 -0.003051  1.000000   0.120589  0.086738  0.033489
# alpha_pv1     -0.023507 -0.016780  0.120589   1.000000  0.433238  0.174759
# alpha4         0.041826  0.021329  0.086738   0.433238  1.000000  0.179539
# alpha3         0.013098  0.070881  0.033489   0.174759  0.179539  1.000000
# alpha6         0.038004 -0.066503 -0.004674   0.027251  0.058389  0.067385
# alpha11        0.070423  0.004022  0.344023   0.097029  0.145994  0.012636
#
#                  alpha6   alpha11
# alpha7         0.015749  0.181646
# alpha9         0.038148  0.062365
# alpha12        0.011518  0.025838
# alpha_nltsmom  0.005007  0.232131
# alpha5        -0.224769 -0.059634
# alpha17        0.038004  0.070423
# alpha2        -0.066503  0.004022
# alpha13       -0.004674  0.344023
# alpha_pv1      0.027251  0.097029
# alpha4         0.058389  0.145994
# alpha3         0.067385  0.012636
# alpha6         1.000000  0.028860
# alpha11        0.028860  1.000000
#                alpha7  alpha9  alpha12  alpha_nltsmom  alpha5  alpha17  \
# alpha7           1272    1272     1272           1272    1272     1272
# alpha9           1272    1272     1272           1272    1272     1272
# alpha12          1272    1272     1272           1272    1272     1266
# alpha_nltsmom    1272    1272     1272           1272    1272     1272
# alpha5           1272    1272     1272           1272    1272     1272
# alpha17          1272    1272     1266           1272    1272     1272
# alpha2           1272    1272     1266           1272    1272     1269
# alpha13          1272    1272     1263           1272    1272     1272
# alpha_pv1        1272    1272     1266           1272    1272     1272
# alpha4           1272    1272     1266           1272    1272     1272
# alpha3           1272    1272     1266           1272    1272     1272
# alpha6           1233    1233     1229           1233    1233     1228
# alpha11           947     947      938            947     947      938
#
#                alpha2  alpha13  alpha_pv1  alpha4  alpha3  alpha6  alpha11
# alpha7           1272     1272       1272    1272    1272    1233      947
# alpha9           1272     1272       1272    1272    1272    1233      947
# alpha12          1266     1263       1266    1266    1266    1229      938
# alpha_nltsmom    1272     1272       1272    1272    1272    1233      947
# alpha5           1272     1272       1272    1272    1272    1233      947
# alpha17          1269     1272       1272    1272    1272    1228      938
# alpha2           1272     1269       1271    1272    1271    1228      947
# alpha13          1269     1272       1272    1272    1272    1233      947
# alpha_pv1        1271     1272       1272    1272    1272    1233      947
# alpha4           1272     1272       1272    1272    1272    1233      947
# alpha3           1271     1272       1272    1272    1272    1233      947
# alpha6           1228     1233       1233    1233    1233    1272      911
# alpha11           947      947        947     947     947     911     1272

# %%
C = C_spear.copy()
N = N_eff.copy()

# --- Factor-level "history quality": how many days do I share with others?
factor_min_N = N.replace(0, np.nan).min(axis=1)
factor_med_N = N.replace(0, np.nan).median(axis=1)

summary_N = pd.DataFrame({
    "min_pairwise_days": factor_min_N,
    "median_pairwise_days": factor_med_N,
}).sort_values("min_pairwise_days")

display(summary_N)

# --- Extract top correlated pairs above a threshold
def top_pairs(C, N, min_abs_corr=0.3, min_days=800, topk=30):
    alphas = list(C.index)
    out = []
    for i in range(len(alphas)):
        for j in range(i+1, len(alphas)):
            a, b = alphas[i], alphas[j]
            cij = C.loc[a, b]
            nij = N.loc[a, b]
            if pd.isna(cij): 
                continue
            if abs(cij) >= min_abs_corr and nij >= min_days:
                out.append((a, b, float(cij), int(nij)))
    out.sort(key=lambda x: abs(x[2]), reverse=True)
    return pd.DataFrame(out, columns=["alpha_i","alpha_j","mean_spearman","N_days"]).head(topk)

display(top_pairs(C, N, min_abs_corr=0.3, min_days=800, topk=50))
# Out:
#                min_pairwise_days  median_pairwise_days
# alpha6                       911                1233.0
# alpha11                      911                 947.0
# alpha12                      938                1266.0
# alpha17                      938                1272.0
# alpha7                       947                1272.0
# alpha9                       947                1272.0
# alpha_nltsmom                947                1272.0
# alpha5                       947                1272.0
# alpha2                       947                1271.0
# alpha13                      947                1272.0
# alpha_pv1                    947                1272.0
# alpha4                       947                1272.0
# alpha3                       947                1272.0
#          alpha_i  alpha_j  mean_spearman  N_days
# 0      alpha_pv1   alpha4       0.433238    1272
# 1  alpha_nltsmom  alpha13       0.413533    1272
# 2        alpha13  alpha11       0.344023     947

# %% [markdown]
# ## Eigenspectrum

# %%
# Use only factors with a fully defined correlation row/col
good = C.notna().all(axis=1)
C0 = C.loc[good, good].copy()

# If any tiny NaNs remain (shouldn't), fill with 0 as a conservative default
C0 = C0.fillna(0.0)

# Ensure symmetry
C0 = (C0 + C0.T) / 2

# Eigenvalues
eigvals = np.linalg.eigvalsh(C0.values)
eigvals_sorted = np.sort(eigvals)[::-1]

# Condition number (avoid division by 0)
eps = 1e-12
cond = float(eigvals_sorted[0] / max(eigvals_sorted[-1], eps))

# Effective rank (entropy-based)
p = np.clip(eigvals_sorted, 0, None)
p = p / (p.sum() + eps)
eff_rank = float(np.exp(-(p * np.log(p + eps)).sum()))

print(f"#factors used: {C0.shape[0]}")
print(f"min eig: {eigvals_sorted[-1]:.6g}  max eig: {eigvals_sorted[0]:.6g}")
print(f"condition number: {cond:.2f}")
print(f"effective rank: {eff_rank:.2f}")

plt.figure()
plt.plot(eigvals_sorted, marker="o")
plt.title("Eigenvalues of factor correlation matrix")
plt.xlabel("Index (sorted desc)")
plt.ylabel("Eigenvalue")
plt.show()
# Out:
# #factors used: 13
# min eig: 0.494856  max eig: 2.02759
# condition number: 4.10
# effective rank: 12.11

# %% [markdown]
# ## Cluster Factors

# %%
try:
    from scipy.cluster.hierarchy import linkage, leaves_list
    from scipy.spatial.distance import squareform

    # distance matrix
    D = 1.0 - np.abs(C0.values)
    np.fill_diagonal(D, 0.0)

    Z = linkage(squareform(D, checks=False), method="average")
    order = leaves_list(Z)
    ordered = C0.iloc[order, order]

except Exception as e:
    print("SciPy clustering not available, using sklearn fallback:", e)
    from sklearn.cluster import AgglomerativeClustering

    D = 1.0 - np.abs(C0.values)
    np.fill_diagonal(D, 0.0)

    model = AgglomerativeClustering(
        metric="precomputed",
        linkage="average",
        n_clusters=None,
        distance_threshold=0.4,   # tune
    )
    labels = model.fit_predict(D)
    order = np.argsort(labels)
    ordered = C0.iloc[order, order]

# Heatmap (matplotlib)
plt.figure(figsize=(8, 6))
plt.imshow(ordered.values, aspect="auto", vmin=-1, vmax=1)
plt.colorbar(label="Mean daily Spearman corr")
plt.xticks(range(len(ordered.columns)), ordered.columns, rotation=90, fontsize=7)
plt.yticks(range(len(ordered.index)), ordered.index, fontsize=7)
plt.title("Factor correlation (cluster-ordered)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Diagnostics: Delete Alpha19

# %%
keep_alphas.remove('alpha19')

# %% [markdown]
# ## 4.2.2 Returns Regression: Fama-Macbeth

# %%
# Use z-scored exposures for regression
# You already have X_z (date x (alpha,ticker)) and R_fwd_s (date x ticker) and sample_mask (date x ticker)
# Ensure these correspond to the same DATE_MASK window already applied.
X_use = X_z.copy()
R_use = R_fwd_s.copy()
M_use = sample_mask.copy()

# --- utilities
def _row_to_matrix(X_row: pd.Series) -> pd.DataFrame:
    """X_row is a Series indexed by MultiIndex (alpha, ticker). Return DataFrame index=ticker, cols=alpha."""
    # X columns are (alpha, ticker), so X_row index is (alpha,ticker)
    # unstack alpha -> index=ticker, cols=alpha
    return X_row.unstack("alpha").sort_index(axis=1)

def fama_macbeth_factor_returns(X_panel: pd.DataFrame,
                               R_fwd: pd.DataFrame,
                               sample_mask: pd.DataFrame,
                               alphas: list[str],
                               add_intercept: bool = True,
                               min_nobs: int = 30,
                               fill_missing_exposure_with_zero: bool = True):
    """
    Estimate daily factor returns via cross-sectional OLS per day.
    X_panel: DataFrame indexed by date, columns MultiIndex (alpha,ticker)
    R_fwd:   DataFrame indexed by date, columns ticker
    sample_mask: boolean DataFrame indexed by date, columns ticker
    """
    dates = X_panel.index.intersection(R_fwd.index).intersection(sample_mask.index)
    betas = []
    meta = []

    for t in dates:
        y = R_fwd.loc[t]
        m = sample_mask.loc[t] & y.notna()
        if m.sum() < min_nobs:
            continue

        X_mat = _row_to_matrix(X_panel.loc[t])  # ticker x alpha
        # restrict to our alpha list and tickers in mask
        X_mat = X_mat.reindex(index=y.index, columns=alphas)
        X_mat = X_mat.loc[m.index[m]]  # only masked tickers
        y_t = y.loc[m.index[m]].astype(float)

        # handle missing exposures
        if fill_missing_exposure_with_zero:
            X_mat = X_mat.fillna(0.0)
        else:
            good = X_mat.notna().all(axis=1)
            X_mat = X_mat.loc[good]
            y_t = y_t.loc[good]

        if len(y_t) < min_nobs:
            continue

        # design matrix
        X_np = X_mat.values
        if add_intercept:
            X_np = np.column_stack([np.ones(len(y_t)), X_np])

        # OLS
        beta, *_ = np.linalg.lstsq(X_np, y_t.values, rcond=None)

        if add_intercept:
            alpha0 = beta[0]
            b = beta[1:]
        else:
            alpha0 = np.nan
            b = beta

        # R^2
        y_hat = X_np @ beta
        ss_res = np.sum((y_t.values - y_hat) ** 2)
        ss_tot = np.sum((y_t.values - y_t.values.mean()) ** 2)
        r2 = 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan

        betas.append(pd.Series(b, index=alphas, name=t))
        meta.append({"date": t, "nobs": int(len(y_t)), "r2": float(r2), "intercept": float(alpha0)})

    B = pd.DataFrame(betas).sort_index()
    stats = pd.DataFrame(meta).set_index("date").sort_index()
    return B, stats

B, fm_stats = fama_macbeth_factor_returns(
    X_panel=X_use,
    R_fwd=R_use,
    sample_mask=M_use,
    alphas=ALPHAS2,
    add_intercept=True,
    min_nobs=30,
    fill_missing_exposure_with_zero=True,
)

print("Factor returns panel B shape:", B.shape)
display(fm_stats.describe())

# --- Factor-return correlation (time-series corr)
corr_beta = B.corr()
display(corr_beta)

# --- Simple significance summary (t-stats assuming iid; optional NW next)
mu = B.mean()
sd = B.std(ddof=1)
tstat = mu / (sd / np.sqrt(B.shape[0]))

summary = pd.DataFrame({"mean_beta": mu, "std_beta": sd, "tstat_iid": tstat}).sort_values("tstat_iid", ascending=False)
display(summary)
# Out:
# Factor returns panel B shape: (1272, 13)
#               nobs           r2    intercept
# count  1272.000000  1272.000000  1272.000000
# mean     47.981132     0.354535     0.000659
# std       1.395042     0.117384     0.012852
# min      43.000000     0.053480    -0.128577
# 25%      48.000000     0.272473    -0.004545
# 50%      48.000000     0.347489     0.000866
# 75%      49.000000     0.425241     0.006608
# max      49.000000     0.789353     0.100367
#                  alpha7    alpha9   alpha12  alpha_nltsmom    alpha5  \
# alpha7         1.000000  0.045712 -0.071752      -0.112073 -0.018848
# alpha9         0.045712  1.000000 -0.075266      -0.190752 -0.050315
# alpha12       -0.071752 -0.075266  1.000000       0.070857 -0.049731
# alpha_nltsmom -0.112073 -0.190752  0.070857       1.000000  0.020273
# alpha5        -0.018848 -0.050315 -0.049731       0.020273  1.000000
# alpha17       -0.031660 -0.074902 -0.009611      -0.046705  0.156112
# alpha2         0.048555  0.087167  0.001896       0.037333 -0.009336
# alpha13       -0.083585 -0.032974 -0.117357      -0.356721 -0.024525
# alpha_pv1      0.026157 -0.005327  0.046623       0.012685 -0.116083
# alpha4        -0.091862  0.036805  0.026567      -0.014345  0.155771
# alpha3         0.176776  0.124596 -0.055934      -0.125079  0.068669
# alpha6         0.048047 -0.017519 -0.010229       0.000256  0.147477
# alpha11       -0.094892  0.038334 -0.004849      -0.117805  0.019432
#
#                 alpha17    alpha2   alpha13  alpha_pv1    alpha4    alpha3  \
# alpha7        -0.031660  0.048555 -0.083585   0.026157 -0.091862  0.176776
# alpha9        -0.074902  0.087167 -0.032974  -0.005327  0.036805  0.124596
# alpha12       -0.009611  0.001896 -0.117357   0.046623  0.026567 -0.055934
# alpha_nltsmom -0.046705  0.037333 -0.356721   0.012685 -0.014345 -0.125079
# alpha5         0.156112 -0.009336 -0.024525  -0.116083  0.155771  0.068669
# alpha17        1.000000 -0.078449  0.087093   0.036066  0.052682  0.026334
# alpha2        -0.078449  1.000000  0.071705   0.039194 -0.062379 -0.023717
# alpha13        0.087093  0.071705  1.000000   0.002055 -0.029946  0.000888
# alpha_pv1      0.036066  0.039194  0.002055   1.000000 -0.428777  0.018055
# alpha4         0.052682 -0.062379 -0.029946  -0.428777  1.000000 -0.236391
# alpha3         0.026334 -0.023717  0.000888   0.018055 -0.236391  1.000000
# alpha6         0.025500 -0.046206 -0.026575  -0.067387 -0.002540 -0.044529
# alpha11       -0.006504 -0.024490 -0.136147  -0.014602 -0.014616  0.101691
#
#                  alpha6   alpha11
# alpha7         0.048047 -0.094892
# alpha9        -0.017519  0.038334
# alpha12       -0.010229 -0.004849
# alpha_nltsmom  0.000256 -0.117805
# alpha5         0.147477  0.019432
# alpha17        0.025500 -0.006504
# alpha2        -0.046206 -0.024490
# alpha13       -0.026575 -0.136147
# alpha_pv1     -0.067387 -0.014602
# alpha4        -0.002540 -0.014616
# alpha3        -0.044529  0.101691
# alpha6         1.000000 -0.008941
# alpha11       -0.008941  1.000000
#                mean_beta  std_beta  tstat_iid
# alpha_pv1       0.000225  0.003217   2.499462
# alpha13         0.000202  0.004134   1.745846
# alpha2          0.000067  0.002748   0.863532
# alpha5          0.000069  0.002897   0.850423
# alpha12         0.000080  0.003497   0.815802
# alpha_nltsmom   0.000099  0.005044   0.702409
# alpha3          0.000059  0.003116   0.680467
# alpha17         0.000004  0.002533   0.061814
# alpha4         -0.000013  0.003597  -0.127774
# alpha6         -0.000023  0.002400  -0.334394
# alpha9         -0.000053  0.002978  -0.640727
# alpha7         -0.000070  0.003163  -0.789826
# alpha11        -0.000102  0.002726  -1.332452

# %% [markdown]
# ## 4.3 ICIR

# %% [markdown]
# ## 4.3.1 Combined

# %%
ALPHAS2 = list(B.columns)

# ---------- 1) Newey–West t-stats (sanity)
def newey_west_tstat(series: pd.Series, L: int = 5):
    x = series.dropna().values
    T = len(x)
    if T < 10:
        return np.nan
    mu = x.mean()
    y = x - mu
    gamma0 = np.dot(y, y) / T
    var = gamma0
    for l in range(1, L + 1):
        w = 1 - l / (L + 1)
        gam = np.dot(y[l:], y[:-l]) / T
        var += 2 * w * gam
    se = np.sqrt(var / T) if var > 0 else np.nan
    return mu / se if (se is not None and se > 0) else np.nan

L_NW = 5  # H=1, so 5 is fine; if you later use H=5/20, set L_NW ~ H or 2H
nw_t = B.apply(lambda s: newey_west_tstat(s, L=L_NW), axis=0)
print("NW t-stats:")
display(nw_t.sort_values(ascending=False))

# ---------- 2) Optional sign alignment (makes interpretation consistent)
mu_full = B.mean()
sign = np.sign(mu_full).replace(0, 1)  # if exactly zero, leave sign = +1

B_sa = B.mul(sign, axis=1)  # factor returns sign-aligned so mean >= 0
# For exposures, apply same sign so "positive score" always means expected positive return
def apply_sign_to_X(X_panel: pd.DataFrame, sign: pd.Series) -> pd.DataFrame:
    X = X_panel.copy()
    # multiply each alpha block by sign[alpha]
    for a, s in sign.items():
        if a in X.columns.get_level_values("alpha"):
            X.loc[:, (a, slice(None))] = X.loc[:, (a, slice(None))] * float(s)
    return X

X_sa = apply_sign_to_X(X_z, sign.loc[ALPHAS2])

# ---------- 3) Rolling factor-space optimizer
def ridge_mv_weights(B_window: pd.DataFrame, ridge: float = 1e-4):
    """
    w ∝ (Sigma + ridge*I)^(-1) mu
    Returns normalized weights with sum(|w|)=1
    """
    mu = B_window.mean().values
    Sigma = np.cov(B_window.values, rowvar=False, ddof=1)
    K = Sigma.shape[0]
    Sigma_r = Sigma + ridge * np.eye(K)
    w = np.linalg.solve(Sigma_r, mu)
    # normalize for stability
    s = np.sum(np.abs(w))
    if s == 0 or np.isnan(s):
        return np.zeros_like(w)
    return w / s

LOOKBACK = 252     # 1y rolling estimation
RIDGE = 1e-3       # increase if weights look noisy; decrease if too flat

dates = B_sa.index
W = pd.DataFrame(index=dates, columns=ALPHAS2, dtype=float)

for t_idx in range(len(dates)):
    t = dates[t_idx]
    # use only past data
    start = max(0, t_idx - LOOKBACK)
    window = B_sa.iloc[start:t_idx]  # excludes current day
    if len(window) < 60:  # require some history
        continue
    w = ridge_mv_weights(window.dropna(), ridge=RIDGE)
    W.loc[t] = w

W = W.dropna(how="all")
print("Weights panel shape:", W.shape)

# ---------- 4) Build combined score S[t, ticker] from X_sa and W
def row_to_Xmat(X_row: pd.Series) -> pd.DataFrame:
    # X_row indexed by (alpha,ticker) -> ticker x alpha
    return X_row.unstack("alpha").reindex(columns=ALPHAS2)

scores = []
score_dates = W.index.intersection(X_sa.index).intersection(R_fwd_s.index)

for t in score_dates:
    w = W.loc[t].astype(float)
    if w.isna().any():
        continue
    Xmat = row_to_Xmat(X_sa.loc[t])
    # apply tradable mask and keep only tickers in sample
    m = sample_mask.loc[t] & R_fwd_s.loc[t].notna()
    Xmat = Xmat.loc[m.index[m]].fillna(0.0)
    s = Xmat.values @ w.values
    scores.append(pd.Series(s, index=Xmat.index, name=t))

S = pd.DataFrame(scores).sort_index()
print("Combined score panel S shape:", S.shape)

# ---------- 5) Evaluate: daily IC of combined score vs forward returns
def daily_ic(score_df: pd.DataFrame, ret_df: pd.DataFrame, method="spearman", min_names=30):
    ics = []
    for t in score_df.index.intersection(ret_df.index):
        s = score_df.loc[t]
        r = ret_df.loc[t]
        m = s.notna() & r.notna()
        if m.sum() >= min_names:
            ics.append((t, s[m].corr(r[m], method=method)))
    return pd.Series(dict(ics)).sort_index()

ic = daily_ic(S, R_fwd_s, method="spearman", min_names=30)
print("IC mean:", float(ic.mean()), "IC std:", float(ic.std()), "ICIR:", float(ic.mean()/ic.std()) if ic.std()>0 else np.nan)
display(ic.describe())
# Out:
# NW t-stats:
# alpha_pv1        2.661885
# alpha13          1.813810
# alpha5           0.843213
# alpha2           0.801958
# alpha_nltsmom    0.738227
# alpha12          0.735746
# alpha3           0.671571
# alpha17          0.063943
# alpha4          -0.136449
# alpha6          -0.330690
# alpha9          -0.577995
# alpha7          -0.813477
# alpha11         -1.294870
# dtype: float64
# Weights panel shape: (1212, 13)
# Combined score panel S shape: (1212, 49)
# IC mean: 0.00471695607086837 IC std: 0.19234512078766194 ICIR: 0.02452339862613734
# count    1212.000000
# mean        0.004717
# std         0.192345
# min        -0.548958
# 25%        -0.125438
# 50%         0.011793
# 75%         0.136518
# max         0.616735
# dtype: float64

# %% [markdown]
# ## 4.3.2 Standalone

# %%
DATE_MASK = R_fwd_s.index  # already masked window
MIN_NAMES = 30

def daily_ic_from_panels(X: pd.DataFrame, R: pd.DataFrame, M: pd.DataFrame,
                         method="spearman", min_names=30) -> pd.Series:
    """Daily cross-sectional IC of X vs R using mask M."""
    idx = X.index.intersection(R.index).intersection(M.index)
    out = {}
    for t in idx:
        x = X.loc[t]
        r = R.loc[t]
        m = M.loc[t] & x.notna() & r.notna()
        if m.sum() >= min_names:
            out[t] = x[m].corr(r[m], method=method)
    return pd.Series(out).sort_index()

ic_by_alpha = {}
for a in ALPHAS2:
    X = alpha_rank[a].loc[DATE_MASK]  # rank exposures
    ic_by_alpha[a] = daily_ic_from_panels(X, R_fwd_s, sample_mask, method="spearman", min_names=MIN_NAMES)

# Summary table
rows = []
for a, s in ic_by_alpha.items():
    mu = float(s.mean())
    sd = float(s.std(ddof=1))
    icir = mu / sd if sd > 0 else np.nan
    rows.append({
        "alpha": a,
        "ic_mean": mu,
        "ic_std": sd,
        "icir": icir,
        "hit_rate": float((s > 0).mean()),
        "n_days": int(s.notna().sum())
    })

ic_table = pd.DataFrame(rows).sort_values("icir", ascending=False).reset_index(drop=True)
display(ic_table)
# Out:
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# ...
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /opt/anaconda3/envs/csi/lib/python3.11/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
#             alpha   ic_mean    ic_std      icir  hit_rate  n_days
# 0       alpha_pv1  0.011061  0.167056  0.066210  0.522013    1272
# 1          alpha2  0.010596  0.167563  0.063235  0.514937    1272
# 2         alpha12  0.013605  0.215498  0.063132  0.534700    1268
# 3          alpha9  0.011411  0.183441  0.062205  0.540094    1272
# 4          alpha5  0.009428  0.178743  0.052744  0.513365    1272
# 5         alpha13  0.009021  0.219836  0.041037  0.518082    1272
# 6          alpha3  0.005072  0.184032  0.027561  0.518082    1272
# 7         alpha17  0.002356  0.161501  0.014588  0.489780    1272
# 8          alpha4 -0.002898  0.182349 -0.015892  0.494497    1272
# 9          alpha7 -0.003315  0.182447 -0.018168  0.486635    1272
# 10  alpha_nltsmom -0.006899  0.250016 -0.027593  0.470912    1272
# 11         alpha6 -0.004159  0.149066 -0.027901  0.472484    1233
# 12        alpha11 -0.005294  0.168364 -0.031444  0.345912     947
